# %% [markdown]
# # Programming Assignment 2

# %%
# Import NumPy as it will be needed below
import numpy as np

# %% [markdown]
# ## General instructions
#
# For this assignment and *all future assignments*, your code must include *comments* and all functions that you write must include *docstrings*. The docstrings should describe what a function does, including what its inputs and outputs are, and comments must explain what your code does and how it works. The comments and docstrings will be part of the grading.

# %% [markdown]
# ## 1. Indexing
#
# This problem develops experience with indexing. Start with the string `string = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"`. See string-list-dict.ipynb for the indexing syntax.
#
# Write an index expression that extracts each of the following character sequences from `string`. The answer for part 1 is provided as an example
# 1. 'CDE' (answer `string[2:5]`)
# 1. 'D'
# 1. 'Y' (use a positive index)
# 1. 'Y' (use a negative index)
# 1. 'KLMNO'
# 1. 'WXYZ'
# 1. 'ACEGIKMOQSUWY'
# 1. 'ACEG'
# 1. 'ZYXWVUTSRQPONMLKJIHGFEDCBA'
# 1. 'ZYXWV'
# 1. 'ZXV'
# 1. 'AEIMQUY'

# %%
string = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
# Write your code here; Comments are not required for this problem

# %% [markdown]
# ## 2. String manipulation
#
# Write a function named `mirror` that mirrors its string argument. For example, if the input is 'Python', then the output should be 'PythonnohtyP'. Include a docstring in your function.

# %%
# Write your code here

# %%
# Do not change this cell!
# Run this cell after writing your function.
# If your function is written correctly, you will get message that it passed.
# If this cell generates an error, your function has a bug.
assert mirror("good") == "gooddoog"
assert mirror("Python") == "PythonnohtyP"
assert mirror("") == ""
assert mirror("a") == "aa"
print('Your function passed the tests')

# %% [markdown]
# Write a function named `repeat_this` that repeats an input string a specified number of times. For example, `repeat_this('Hi',3)` should produce 'HiHiHi'.
#
# After your function works, modify it make the number an optional argument with a default value of 0, so that `repeat_this('Hi')` returns '' (empty string).
#
# Include a docstring in your function.

# %%
# Write your code here

# %%
# Do not change this cell!
# Run this cell after writing your function.
# If your function is written correctly, you will get message that it passed.
# If this cell generates an error, your function has a bug.
assert repeat_this("abc", 3) == "abcabcabc", "Test case 1 failed"
assert repeat_this("xyz", 0) == "", "Test case 2 failed"
assert repeat_this("123", 2) == "123123", "Test case 3 failed"
assert repeat_this("", 5) == "", "Test case 4 failed"
print('Your function passed the tests with specified number of repeats')

# %%
# Do not change this cell!
# Run this cell after writing your function.
# If your function is written correctly, you will get message that it passed.
# If this cell generates an error, your function has a bug.
assert repeat_this("abc") == ""
print('Your function passed the tests with default number of repeats')

# %% [markdown]
# ## 3. Formatting data with f-strings
#
# Create an f-string that incorporates the variables 'state', 'capital' and 'population' into a sentence that says,
#
# `The capital of Florida is Tallahassee with a population of 205089 or 2.05e+05 in 2024.`

# %%
state = "Florida"
capital = "Tallahassee"
population = 205089
year = 2024
# Write your code here

# %% [markdown]
# ## 4. Iteration with `for` and `range()`
#
# In each part below, write a separate `for` loop that prints the numbers shown. Use the `range()` function in your solution.
#
# Print this sequence
# ```python
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# ```

# %%
# Write your code here

# %% [markdown]
# Print this sequence
# ```python
# 21
# 22
# 23
# 24
# 25
# ```

# %%
# Write your code here

# %% [markdown]
# Print this sequence
# ```python
# 100
# 150
# 200
# 250
# 300
# ```

# %%
# Write your code here

# %% [markdown]
# Write function named `sum_up` that computes the sum of numbers up to and including an input integer $n$. For example, `sum_up(4)` should return 10 because 1 + 2 + 3 + 4 = 10. You function should contain a `for` loop.
#
#
# <details>
#     <summary>Hint</summary>
#     * Create a variable named `total` with an initial value of 0 and add to it within the loop.
# </details>

# %%
# Write your code here

# %%
# Do not change this cell!
# Run this cell after writing your function.
# If your function is written correctly, you will get message that it passed.
# If this cell generates an error, your function has a bug.
assert sum_up(4) == 10, "Test with n=4 failed"
assert sum_up(100) == 5050, "Test with n=100 failed"
assert sum_up(1) == 1, "Test with n=1 failed"
assert sum_up(0) == 0, "Test with n=0 failed"
print('Your function passed the tests')

# %% [markdown]
# Write function named `sum_up_odd` that computes the sum of /odd/ numbers up to and including an input integer $n$. For example, `sum_up_odd(5)` should return 9 because 1 + 3 + 5 = 9. The functions `sum_up_odd` and `sum_up` will have a lot of similarities.
#
#
# <details>
#     <summary>Hint</summary>
#     `number % 2` (modulo 2) is one way to distinguish odd and even numbers in an `if` statement. However, there are ways to solve this problem without using `%`.
# </details>

# %%
# Write your code here

# %%
# Do not change this cell!
# Run this cell after writing your function.
# If your function is written correctly, you will get message that it passed.
# If this cell generates an error, your function has a bug.
assert sum_up_odd(5) == 9, "Test with n=5 failed"
assert sum_up_odd(6) == 9, "Test with n=6 failed"
assert sum_up_odd(100) == 2500, "Test with n=100 failed"
assert sum_up_odd(1) == 1, "Test with n=1 failed"
assert sum_up_odd(0) == 0, "Test with n=0 failed"
print('Your function passed the tests')

# %% [markdown]
# ## 5. Iteration with a list of items
#
# 1. Write a `for` loop that inserts the words "California", "Texas", "New York", and "Alaska" into the sentence, "I would like to visit [state] this year."
# 1. Make each state name 10 characters wide, so that the sentences align as follows.
#
# Your output should be
# ```python
# I would like to visit California this year.
# I would like to visit Texas      this year.
# I would like to visit New York   this year.
# I would like to visit Alaska     this year.
# ```

# %%
# Write your code here
