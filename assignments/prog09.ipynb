# %% [markdown]
# # Programming Assignment 9

# %% [markdown]
# ## 0. Preliminary
#
# Import pandas, numpy, and matplotlib.pyplot here, using the customary aliases for each.

# %%
# Write your code here

# %%
# SOLUTION
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Read files with pandas
#
# This task builds experience in reading tabular data files with pandas.
#
# All of the files are in the `prog09_files` directory.
#
# Follow these steps for each part:
#
# 0. Open the file with a text editor to see the original data. Inspect the following.
#     - How are the columns separated? (commas, spaces, something else?)
#     - Number and Names of columns/variables
#     - Values expected in first few rows
#     - How are missing data represented?
#     - Does the file have any comments and how are they marked?
#     - What column contains the time?
# 1. Try reading the file with `read_csv()`
# 2. Check results with `head()`, `info()`, and `describe()` to check if results look correct.
# 3. Add keywords as necessary: `comment=`, `na_values=`, `sep=`, `parse_dates=`
# 4. Repeat steps 1-3 until results look correct.
# 5. Add code to print 'The mean temeprature is XX.X', where XX.X is the temperature

# %% [markdown]
# #### 1a. KTLH (Tallahassee)

# %%
filename_ktlh = 'prog09_files/met_ktlh.csv'
# Write your code here

# In comments here, describe your process and how you checked whether the results were correct

# %% [markdown]
# #### 1b. KJAX (Jacksonville)

# %%
filename_kjax = 'prog09_files/met_kjax.csv'
# Write your code here

# In comments here, describe your process and how you checked whether the results were correct

# %% [markdown]
# #### 1c. KMCO (Orlando)

# %%
filename_kmco = 'prog09_files/met_kmco.txt'
# Write your code here

# In comments here, describe your process and how you checked whether the results were correct

# %% [markdown]
# #### 1d. KMIA (Miami)

# %%
filename_kmia = 'prog09_files/met_kmia.txt'
# Write your code here

# In comments here, describe your process and how you checked whether the results were correct

# %% [markdown]
# ## 2. Mauna Loa CO<sub>2</sub>
#
# NOAA has measured atmospheric CO<sub>2</sub> at Mauna Loa, HI since 1974. The file `prog09_files/co2_daily_mlo.csv` contains those measurements at daily time resolution. The units for CO<sub>2</sub> mole fraction are parts per million (ppm).
#
# 1. Open the csv file in a text editor to get a sense of the format and contents.
# 2. Try reading the file with pandas `read_csv`. You will probably get a `ParserError` saying (among other things) `"Expected 1 fields in line 8, saw 2"`. Take a look at line 8 in the csv file and you'll see that this line doesn't contain data and pandas should ignore this line.
# 3. Read or search the [pandas `read_csv` documentation](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) to see how to ignore "comment" lines in a csv file.
# 4. Modify your `read_csv` command to ignore comments. Ask an instructor if you get stuck.
# 5. Use `pd.to_datetime` to construct and add a new column named 'date' to your DataFrame. Ask an instructor if you get stuck.
# 6. Set the date as the index for your DataFrame.
# 7. Write a command that identifies and prints the first day when CO2 exceeded 390 ppm. (It may be helpful to know that the index of a DataFrame is accessed using `df.index`.)
# 8. Replicate the following figure as closely as you can. (For panel layout, Matplotlib commands that you learned last week are recommended. Documentation for [`pd.DataFrame.plot`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html) may also be useful. The example figure is 9" wide and 4" tall.)
# ![mlo_daily.png](attachment:2b28c80a-a8f5-4cae-bc37-1c39b1bcbc08.png)

# %%
# Write your code here

# %% [markdown]
# ## 3. Temporal resampling Mauna Loa CO<sub>2</sub>
#
# 1. Resample the Mauna Loa CO<sub>2</sub> measurements to monthly and annual frequency.
# 2. Use the resampled data to replicate the following figure as closely as possible. (See note below figure for detailed explanation of the figure elements.)
# 3. Save your figure with the filename 'mlo_resampled.png' and a resolution of 150 dpi.
# ![mlo_resampled.png](attachment:fbc22302-a6d9-4bbc-b7d3-ce5e06529b9c.png)
#
# (Black circles show the monthly mean. Red diamonds show the annual mean. Vertical black lines (error bars) show the standard deviation of the daily data within each month. The gray shading shows the range from the minimum to maximum within each month. The figure size is 5" wide and 4" high.)

# %%
# Write your code here
